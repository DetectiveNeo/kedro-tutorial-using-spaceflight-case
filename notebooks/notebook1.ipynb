# %%
import pandas as pd
import numpy as np

# %%
companies = pd.read_csv("companies.csv")
reviews = pd.read_csv("reviews.csv")
shuttles = pd.read_excel("shuttles.xlsx")

# %%
companies.head()
# Out:
#       id company_rating       company_location  total_fleet_count  \
# 0  35029           100%                   Niue                4.0
# 1  30292            67%               Anguilla                6.0
# 2  19032            67%     Russian Federation                4.0
# 3   8238            91%               Barbados               15.0
# 4  30342            NaN  Sao Tome and Principe                2.0
#
#   iata_approved
# 0             f
# 1             f
# 2             f
# 3             t
# 4             t

# %%
reviews.head()
# Out:
#    shuttle_id  review_scores_rating  review_scores_comfort  \
# 0       63561                  97.0                   10.0
# 1       36260                  90.0                    8.0
# 2       57015                  95.0                    9.0
# 3       14035                  93.0                   10.0
# 4       10036                  98.0                   10.0
#
#    review_scores_amenities  review_scores_trip  review_scores_crew  \
# 0                      9.0                10.0                10.0
# 1                      9.0                10.0                 9.0
# 2                     10.0                 9.0                10.0
# 3                      9.0                 9.0                 9.0
# 4                     10.0                10.0                10.0
#
#    review_scores_location  review_scores_price  number_of_reviews  \
# 0                     9.0                 10.0                133
# 1                     9.0                  9.0                  3
# 2                     9.0                  9.0                 14
# 3                    10.0                  9.0                 39
# 4                     9.0                  9.0                 92
#
#    reviews_per_month
# 0               1.65
# 1               0.09
# 2               0.14
# 3               0.42
# 4               0.94

# %%
shuttles.head()
# Out:
#       id       shuttle_location shuttle_type engine_type       engine_vendor  \
# 0  63561                   Niue      Type V5     Quantum  ThetaBase Services
# 1  36260               Anguilla      Type V5     Quantum  ThetaBase Services
# 2  57015     Russian Federation      Type V5     Quantum  ThetaBase Services
# 3  14035               Barbados      Type V5      Plasma  ThetaBase Services
# 4  10036  Sao Tome and Principe      Type V2      Plasma  ThetaBase Services
#
#    engines  passenger_capacity cancellation_policy  crew d_check_complete  \
# 0      1.0                   2              strict   1.0                f
# 1      1.0                   2              strict   1.0                t
# 2      1.0                   2            moderate   0.0                f
# 3      3.0                   6              strict   3.0                f
# 4      2.0                   4              strict   2.0                f
#
#   moon_clearance_complete     price  company_id
# 0                       f  $1,325.0       35029
# 1                       f  $1,780.0       30292
# 2                       f  $1,715.0       19032
# 3                       f  $4,770.0        8238
# 4                       f  $2,820.0       30342

# %% [markdown]
# ### Define General Function for Preprocessing

# %%
# change the "t" and "f" into true false

def _is_true(x:pd.Series)->pd.Series:
    return x=="t"

#function example
#_is_true(shuttles.d_check_complete)

# %%
# parsing the money data by remove "$" and ","  ex: $1,325.0 -> 1325.o

def _parse_money(x:pd.Series)->pd.Series:
    x=x.str.replace("$","").str.replace(",","")
    x=x.astype(float)
    return x

#function example
#_parse_money(shuttles.price)

# %%
# parsing the percantege data by remove "%",  ex: 67% -> 0.67

def _parse_percentage(x:pd.Series)->pd.Series:
    x=x.str.replace("%","")
    x=x.astype(float)/100
    return x

#function example
_parse_percentage(companies['company_rating'])
# Out:
# 0        1.00
# 1        0.67
# 2        0.67
# 3        0.91
# 4         NaN
#          ...
# 77091    1.00
# 77092     NaN
# 77093     NaN
# 77094    0.80
# 77095    0.98
# Name: company_rating, Length: 77096, dtype: float64

# %% [markdown]
# ### Preprocessing Companies Dataset

# %%
def preprocess_companies(companies:pd.DataFrame)->pd.DataFrame:
    """Preprocesses the data for companies.

    Args:
        companies: Raw data.
    Returns:
        Preprocessed data, with `company_rating` converted to a float and
        `iata_approved` converted to boolean.
    """
    companies['company_rating']=_parse_percentage(companies['company_rating'])
    companies['iata_approved']=_is_true(companies['iata_approved'])
    return companies

preprocess_companies(companies)
# Out:
#           id  company_rating       company_location  total_fleet_count  \
# 0      35029            1.00                   Niue                4.0
# 1      30292            0.67               Anguilla                6.0
# 2      19032            0.67     Russian Federation                4.0
# 3       8238            0.91               Barbados               15.0
# 4      30342             NaN  Sao Tome and Principe                2.0
# ...      ...             ...                    ...                ...
# 77091   6654            1.00                  Tonga                3.0
# 77092   8000             NaN                  Chile                2.0
# 77093  14296             NaN            Netherlands                4.0
# 77094  27363            0.80                    NaN                3.0
# 77095  12542            0.98             Mauritania               19.0
#
#        iata_approved
# 0              False
# 1              False
# 2              False
# 3               True
# 4               True
# ...              ...
# 77091          False
# 77092           True
# 77093          False
# 77094           True
# 77095           True
#
# [77096 rows x 5 columns]

# %% [markdown]
# ### Preprocessing Shuttles Dataset

# %%
def preprocess_shuttles(shuttles: pd.DataFrame) -> pd.DataFrame:
    """Preprocesses the data for shuttles.

    Args:
        shuttles: Raw data.
    Returns:
        Preprocessed data, with `price` converted to a float and `d_check_complete`,
        `moon_clearance_complete` converted to boolean.
    """
    shuttles['price']=_parse_money(shuttles['price'])
    shuttles['moon_clearance_complete']=_is_true(shuttles['moon_clearance_complete'])
    shuttles['d_check_complete']=_is_true(shuttles['d_check_complete'])
    return shuttles

# function example
preprocess_shuttles(shuttles)
# Out:
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   after removing the cwd from sys.path.
#           id           shuttle_location shuttle_type engine_type  \
# 0      63561                       Niue      Type V5     Quantum
# 1      36260                   Anguilla      Type V5     Quantum
# 2      57015         Russian Federation      Type V5     Quantum
# 3      14035                   Barbados      Type V5      Plasma
# 4      10036      Sao Tome and Principe      Type V2      Plasma
# ...      ...                        ...          ...         ...
# 77091   4368                   Barbados      Type V5     Quantum
# 77092   2983  Bouvet Island (Bouvetoya)      Type F5     Quantum
# 77093  69684                 Micronesia      Type V5      Plasma
# 77094  21738                 Uzbekistan      Type V5      Plasma
# 77095  72645                      Malta      Type F5     Quantum
#
#             engine_vendor  engines  passenger_capacity cancellation_policy  \
# 0      ThetaBase Services      1.0                   2              strict
# 1      ThetaBase Services      1.0                   2              strict
# 2      ThetaBase Services      1.0                   2            moderate
# 3      ThetaBase Services      3.0                   6              strict
# 4      ThetaBase Services      2.0                   4              strict
# ...                   ...      ...                 ...                 ...
# 77091  ThetaBase Services      2.0                   4            flexible
# 77092  ThetaBase Services      1.0                   1            flexible
# 77093  ThetaBase Services      0.0                   2            flexible
# 77094  ThetaBase Services      1.0                   2            flexible
# 77095  ThetaBase Services      0.0                   2            moderate
#
#        crew  d_check_complete  moon_clearance_complete   price  company_id
# 0       1.0             False                    False  1325.0       35029
# 1       1.0              True                    False  1780.0       30292
# 2       0.0             False                    False  1715.0       19032
# 3       3.0             False                    False  4770.0        8238
# 4       2.0             False                    False  2820.0       30342
# ...     ...               ...                      ...     ...         ...
# 77091   2.0              True                    False  4107.0        6654
# 77092   1.0              True                    False  1169.0        8000
# 77093   1.0              True                    False  1910.0       14296
# 77094   1.0              True                    False  2170.0       27363
# 77095   2.0              True                    False  1455.0       12542
#
# [77096 rows x 13 columns]

# %%
def preprocess_companies(companies:pd.DataFrame)->pd.DataFrame:
    """Preprocesses the data for companies.

    Args:
        companies: Raw data.
    Returns:
        Preprocessed data, with `company_rating` converted to a float and
        `iata_approved` converted to boolean.
    """
    companies['company_rating']=_parse_percentage(companies['company_rating'])
    companies['iata_approved']=_is_true(companies['iata_approved'])
    return companies
     
# function example
preprocess_companies(companies)


def preprocess_shuttles(shuttles: pd.DataFrame) -> pd.DataFrame:
    """Preprocesses the data for shuttles.

    Args:
        shuttles: Raw data.
    Returns:
        Preprocessed data, with `price` converted to a float and `d_check_complete`,
        `moon_clearance_complete` converted to boolean.
    """
    shuttles['price']=_parse_money(shuttles['price'])
    shuttles['moon_clearance_complete']=_is_true(shuttles['moon_clearance_complete'])
    shuttles['d_check_complete']=_is_true(shuttles['d_check_complete'])
    return shuttles

# function example
preprocess_shuttles(shuttles)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-b35de43dd87e> in <module>
#      13
#      14 # function example
# ---> 15 preprocess_companies(companies)
#      16
#      17
#
# <ipython-input-54-b35de43dd87e> in preprocess_companies(companies)
#       8         `iata_approved` converted to boolean.
#       9     """
# ---> 10     companies['company_rating']=_parse_percentage(companies['company_rating'])
#      11     companies['iata_approved']=_is_true(companies['iata_approved'])
#      12     return companies
#
# <ipython-input-51-d2f8ad129f3a> in _parse_percentage(x)
#       2
#       3 def _parse_percentage(x:pd.Series)->pd.Series:
# ----> 4     x=x.str.replace("%","")
#       5     x=x.astype(float)/100
#       6     return x
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     179             # we're accessing the attribute of the class, i.e., Dataset.geo
#     180             return self._accessor
# --> 181         accessor_obj = self._accessor(obj)
#     182         # Replace the property with the accessor object. Inspired by:
#     183         # https://www.pydanny.com/cached-property.html
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\strings\accessor.py in __init__(self, data)
#     166         from pandas.core.arrays.string_ import StringDtype
#     167
# --> 168         self._inferred_dtype = self._validate(data)
#     169         self._is_categorical = is_categorical_dtype(data.dtype)
#     170         self._is_string = isinstance(data.dtype, StringDtype)
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\strings\accessor.py in _validate(data)
#     223
#     224         if inferred_dtype not in allowed_types:
# --> 225             raise AttributeError("Can only use .str accessor with string values!")
#     226         return inferred_dtype
#     227
#
# AttributeError: Can only use .str accessor with string values!

# %%
def create_model_input_table(
    shuttles: pd.DataFrame, companies: pd.DataFrame, reviews: pd.DataFrame
) -> pd.DataFrame:
    """Combines all data to create a model input table.

    Args:
        shuttles: Preprocessed data for shuttles.
        companies: Preprocessed data for companies.
        reviews: Raw data for reviews.
    Returns:
        model input table.

    """
    rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")
    model_input_table = rated_shuttles.merge(
        companies, left_on="company_id", right_on="id"
    )
    model_input_table = model_input_table.dropna()
    return model_input_table

# %%
create_model_input_table(companies,shuttles,reviews)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-44-b942f889e5e2> in <module>
# ----> 1 create_model_input_table(companies,shuttles,reviews)
#
# <ipython-input-43-313bdf4816c8> in create_model_input_table(shuttles, companies, reviews)
#      14     rated_shuttles = shuttles.merge(reviews, left_on="id", right_on="shuttle_id")
#      15     model_input_table = rated_shuttles.merge(
# ---> 16         companies, left_on="company_id", right_on="id"
#      17     )
#      18     model_input_table = model_input_table.dropna()
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\frame.py in merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9201             copy=copy,
#    9202             indicator=indicator,
# -> 9203             validate=validate,
#    9204         )
#    9205
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1107                         right_keys.append(rk)
#    1108                     if lk is not None:
# -> 1109                         left_keys.append(left._get_label_or_level_values(lk))
#    1110                         join_names.append(lk)
#    1111                     else:
#
# c:\Users\luthf\AppData\Local\Programs\Python\Python37\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'company_id'
